# %%
import billboard
import spotipy
import pandas as pd

# %%
chart = billboard.ChartData('hot-100', date='2018-11-10')

# %%
dummychart = billboard.ChartData('hot-100', date='2018-11-10')

# %%
chart1 = billboard.ChartData('hot-100', date='1999-01-01')
i =0
while chart1.previousDate:
    i = i+1
    chart1 = billboard.ChartData('hot-100', chart1.previousDate)
    #print(chart1.previousDate)
    if(chart1.previousDate <= '1998-09-30'):
        break;
print(i)
# Out:
# 13

# %%
def getData(date1, date2):
    chart = billboard.ChartData('hot-100', date1)
    list = []
    while chart.previousDate:
        date = chart.previousDate
        chart = billboard.ChartData('hot-100', chart.previousDate)
        i = 0;
        temptuples = ()
        
        while (i<100) :
            temptuples = (i, date, chart[i].title,chart[i].artist, chart[i].peakPos, chart[i].lastPos, chart[i].weeks, chart[i].rank, chart[i].isNew)
            i = i+1
            list.append(temptuples)
        if(chart.previousDate <= date2):
            break;
    
    return list

        
#print("Chart: ", date, "  ", chart[0].title, " ", chart[0].artist, " ", chart[0].peakPos, " ", chart[0].lastPos," ", chart[0].weeks," ", chart[0].rank," ", chart[0].isNew )

# %%
finaldatalist1 = getData('2018-11-17', '2000-01-01')
#'1958-08-10'

# %%
len(finaldatalist1)
# Out:
# 98500

# %%
finaldatalist2 = getData('1999-12-31', '1985-01-01')

# %%
len(finaldatalist2)
# Out:
# 78200

# %%
#finaldatalist3_1 = getData('1984-12-31', '1980-01-01')

# %%
#len(finaldatalist3_1)
# Out:
# 26100

# %%
#finaldatalist3_2 = getData('1974-12-31', '1970-01-01')

# %%
#finaldatalist3_3 = getData('1979-12-31', '1978-01-01')

# %%
finaldatalist3_11 = getData('1984-12-31', '1978-01-01')

# %%
finaldatalist3_22 = getData('1974-12-31', '1970-01-01')

# %%
finaldatalist4 = getData('1969-12-31', '1958-08-10')

# %%
df = pd.DataFrame(finaldatalist1, columns=['i', 'date', 'chart[i].title','chart[i].artist', 'chart[i].peakPos', 'chart[i].lastPos', 'chart[i].weeks', 'chart[i].rank', 'chart[i].isNew'])

# %%
df.head(10)
# Out:
#    i        date  chart[i].title                              chart[i].artist  \
# 0  0  2018-11-10  Girls Like You                   Maroon 5 Featuring Cardi B
# 1  1  2018-11-10      Sicko Mode                                 Travis Scott
# 2  2  2018-11-10         Happier                        Marshmello & Bastille
# 3  3  2018-11-10    Lucid Dreams                                   Juice WRLD
# 4  4  2018-11-10      Better Now                                  Post Malone
# 5  5  2018-11-10            ZEZE  Kodak Black Featuring Travis Scott & Offset
# 6  6  2018-11-10      Youngblood                          5 Seconds Of Summer
# 7  7  2018-11-10   Drip Too Hard                             Lil Baby & Gunna
# 8  8  2018-11-10      Without Me                                       Halsey
# 9  9  2018-11-10        Mo Bamba                                    Sheck Wes
#
#    chart[i].peakPos  chart[i].lastPos  chart[i].weeks  chart[i].rank  \
# 0                 1                 1              23              1
# 1                 2                 2              13              2
# 2                 3                 4              11              3
# 3                 2                 3              25              4
# 4                 3                 5              27              5
# 5                 2                 6               3              6
# 6                 7                 7              22              7
# 7                 4                 8               7              8
# 8                 9                12               4              9
# 9                10                16              10             10
#
#    chart[i].isNew
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False

# %%
df.shape
# Out:
# (98500, 9)

# %%
df_1 = pd.DataFrame(finaldatalist1, columns=['i', 'date', 'title','artist', 'peakPos', 'lastPos', 'weeks', 'rank', 'isNew'])
df_2 = pd.DataFrame(finaldatalist2, columns=['i', 'date', 'title','artist', 'peakPos', 'lastPos', 'weeks', 'rank', 'isNew'])
df_3 = pd.DataFrame(finaldatalist3_11, columns=['i', 'date', 'title','artist', 'peakPos', 'lastPos', 'weeks', 'rank', 'isNew'])
df_4 = pd.DataFrame(finaldatalist3_22, columns=['i', 'date', 'title','artist', 'peakPos', 'lastPos', 'weeks', 'rank', 'isNew'])
df_5 = pd.DataFrame(finaldatalist4, columns=['i', 'date', 'title','artist', 'peakPos', 'lastPos', 'weeks', 'rank', 'isNew'])

# %%
data_set = pd.concat([df_5,df_4], axis=0)
print(data_set.shape)
# Out:
# (85500, 9)
# (59400, 9)

# %%
data_set = pd.concat([data_set,df_3], axis=0)
data_set = pd.concat([data_set,df_2], axis=0)
data_set = pd.concat([data_set,df_1], axis=0)
print(data_set.shape)
# Out:
# (298700, 9)

# %%
data_set.tail(10)
# Out:
#         i        date                         title  \
# 98490  90  2000-01-08                  Left & Right
# 98491  91  2000-01-08         The Rockafeller Skank
# 98492  92  2000-01-08  She Thinks My Tractor's Sexy
# 98493  93  2000-01-08                 Love Is Blind
# 98494  94  2000-01-08             Live, Laugh, Love
# 98495  95  2000-01-08              Larger Than Life
# 98496  96  2000-01-08         The Best Man I Can Be
# 98497  97  2000-01-08                     L.A. Song
# 98498  98  2000-01-08                   Re-arranged
# 98499  99  2000-01-08             The Quittin' Kind
#
#                                          artist  peakPos  lastPos  weeks  \
# 98490  D'Angelo Featuring Method Man And Redman       70       70      5
# 98491                               Fatboy Slim       77       90     25
# 98492                             Kenny Chesney       74       86      8
# 98493                 Eve Featuring Faith Evans       94        0      0
# 98494                               Clay Walker       84       84      6
# 98495                           Backstreet Boys       25       87     17
# 98496              Ginuwine, R.L., Tyrese, Case       97        0      0
# 98497                                 Beth Hart       96       96      7
# 98498                               Limp Bizkit       90       95      6
# 98499                                Joe Diffie       98       98      2
#
#        rank  isNew
# 98490    91  False
# 98491    92  False
# 98492    93  False
# 98493    94   True
# 98494    95  False
# 98495    96  False
# 98496    97   True
# 98497    98  False
# 98498    99  False
# 98499   100  False

# %%
data_set.head()
# Out:
#    i        date                              title  \
# 0  0  1969-12-27          Someday We'll Be Together
# 1  1  1969-12-27             Leaving On A Jet Plane
# 2  2  1969-12-27  Raindrops Keep Fallin' On My Head
# 3  3  1969-12-27   Down On The Corner/Fortunate Son
# 4  4  1969-12-27     Na Na Hey Hey Kiss Him Goodbye
#
#                          artist  peakPos  lastPos  weeks  rank  isNew
# 0     Diana Ross & The Supremes        1        2      8     1  False
# 1            Peter, Paul & Mary        1        1     10     2  False
# 2                   B.J. Thomas        3        5      9     3  False
# 3  Creedence Clearwater Revival        3        3     10     4  False
# 4                         Steam        1        4     11     5  False

# %%
data_set.to_csv('bilboard_data.csv', sep=",")

# %%
data_set = data_set.sort_values(by='date')
data_set.tail(10)
# Out:
#      i        date               title  \
# 64  64  2018-11-10             Stoopid
# 65  65  2018-11-10      Drew Barrymore
# 66  66  2018-11-10             You Say
# 67  67  2018-11-10    W O R K I N  M E
# 68  68  2018-11-10         Jackie Chan
# 69  69  2018-11-10           Mona Lisa
# 70  70  2018-11-10         Blue Tacoma
# 72  72  2018-11-10          No Stylist
# 61  61  2018-11-10        That's On Me
# 99  99  2018-11-10  Drowns The Whiskey
#
#                                           artist  peakPos  lastPos  weeks  \
# 64               6ix9ine Featuring Bobby Shmurda       25       48      4
# 65                                    Bryce Vine       46       64     12
# 66                                 Lauren Daigle       44       75     16
# 67                                         Quavo       52       59     12
# 68  Tiesto & Dzeko Featuring Preme & Post Malone       52       60     17
# 69            Lil Wayne Featuring Kendrick Lamar        2       55      5
# 70                             Russell Dickerson       52       70     11
# 72                French Montana Featuring Drake       47       68      6
# 61                                   Yella Beezy       62       86     14
# 99        Jason Aldean Featuring Miranda Lambert       32       99     19
#
#     rank  isNew
# 64    65  False
# 65    66  False
# 66    67  False
# 67    68  False
# 68    69  False
# 69    70  False
# 70    71  False
# 72    73  False
# 61    62  False
# 99   100  False

# %%
data_set = data_set.reset_index()
data_set.tail(10)
# Out:
#         index   i        date               title  \
# 298690     64  64  2018-11-10             Stoopid
# 298691     65  65  2018-11-10      Drew Barrymore
# 298692     66  66  2018-11-10             You Say
# 298693     67  67  2018-11-10    W O R K I N  M E
# 298694     68  68  2018-11-10         Jackie Chan
# 298695     69  69  2018-11-10           Mona Lisa
# 298696     70  70  2018-11-10         Blue Tacoma
# 298697     72  72  2018-11-10          No Stylist
# 298698     61  61  2018-11-10        That's On Me
# 298699     99  99  2018-11-10  Drowns The Whiskey
#
#                                               artist  peakPos  lastPos  weeks  \
# 298690               6ix9ine Featuring Bobby Shmurda       25       48      4
# 298691                                    Bryce Vine       46       64     12
# 298692                                 Lauren Daigle       44       75     16
# 298693                                         Quavo       52       59     12
# 298694  Tiesto & Dzeko Featuring Preme & Post Malone       52       60     17
# 298695            Lil Wayne Featuring Kendrick Lamar        2       55      5
# 298696                             Russell Dickerson       52       70     11
# 298697                French Montana Featuring Drake       47       68      6
# 298698                                   Yella Beezy       62       86     14
# 298699        Jason Aldean Featuring Miranda Lambert       32       99     19
#
#         rank  isNew
# 298690    65  False
# 298691    66  False
# 298692    67  False
# 298693    68  False
# 298694    69  False
# 298695    70  False
# 298696    71  False
# 298697    73  False
# 298698    62  False
# 298699   100  False

# %%
data_set.to_csv('bilboard_new_data.csv', sep=",")

# %%
new_data = data_set.groupby(by='title').describe()

# %%
new_data.columns.tolist()
# Out:
# [('i', 'count'),
#  ('i', 'mean'),
#  ('i', 'std'),
#  ('i', 'min'),
#  ('i', '25%'),
#  ('i', '50%'),
#  ('i', '75%'),
#  ('i', 'max'),
#  ('index', 'count'),
#  ('index', 'mean'),
#  ('index', 'std'),
#  ('index', 'min'),
#  ('index', '25%'),
#  ('index', '50%'),
#  ('index', '75%'),
#  ('index', 'max'),
#  ('lastPos', 'count'),
#  ('lastPos', 'mean'),
#  ('lastPos', 'std'),
#  ('lastPos', 'min'),
#  ('lastPos', '25%'),
#  ('lastPos', '50%'),
#  ('lastPos', '75%'),
#  ('lastPos', 'max'),
#  ('peakPos', 'count'),
#  ('peakPos', 'mean'),
#  ('peakPos', 'std'),
#  ('peakPos', 'min'),
#  ('peakPos', '25%'),
#  ('peakPos', '50%'),
#  ('peakPos', '75%'),
#  ('peakPos', 'max'),
#  ('rank', 'count'),
#  ('rank', 'mean'),
#  ('rank', 'std'),
#  ('rank', 'min'),
#  ('rank', '25%'),
#  ('rank', '50%'),
#  ('rank', '75%'),
#  ('rank', 'max'),
#  ('weeks', 'count'),
#  ('weeks', 'mean'),
#  ('weeks', 'std'),
#  ('weeks', 'min'),
#  ('weeks', '25%'),
#  ('weeks', '50%'),
#  ('weeks', '75%'),
#  ('weeks', 'max')]
